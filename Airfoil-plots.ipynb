# %% [markdown]
# NACA 66-206 Airfoil Plot

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# NACA 66-206 coordinates
upper = [
    (1.00000, 0.00000), (0.95012, 0.00578), (0.90023, 0.01182),
    (0.85031, 0.01780), (0.80034, 0.02339), (0.75034, 0.02848),
    (0.70031, 0.03288), (0.65026, 0.03641), (0.60018, 0.03886),
    (0.55009, 0.04020), (0.50000, 0.04088), (0.44990, 0.04095),
    (0.39981, 0.04042), (0.34971, 0.03929), (0.29962, 0.03754),
    (0.24954, 0.03513), (0.19947, 0.03196), (0.14942, 0.02791),
    (0.09939, 0.02268), (0.07439, 0.01947), (0.04941, 0.01572),
    (0.02447, 0.01102), (0.01202, 0.00798), (0.00707, 0.00622),
    (0.00461, 0.00509), (0.00000, 0.00000),
]

lower = [
    (0.00000, 0.00000), (0.00539, -0.00409), (0.00793, -0.00482),
    (0.01298, -0.00584), (0.02553, -0.00730), (0.05059, -0.00940),
    (0.07561, -0.01099), (0.10061, -0.01234), (0.15058, -0.01445),
    (0.20053, -0.01604), (0.25046, -0.01723), (0.30038, -0.01810),
    (0.35029, -0.01869), (0.40019, -0.01900), (0.45010, -0.01905),
    (0.50000, -0.01882), (0.54991, -0.01830), (0.59982, -0.01744),
    (0.64974, -0.01581), (0.69969, -0.01344), (0.74966, -0.01058),
    (0.79966, -0.00747), (0.84969, -0.00434), (0.89977, -0.00148),
    (0.94988, 0.00054), (1.00000, 0.00000),
]

xu, yu = zip(*upper)
xl, yl = zip(*lower)

# Compute camber line
xu_arr, yu_arr = np.array(xu), np.array(yu)
xl_arr, yl_arr = np.array(xl), np.array(yl)

# Interpolate lower surface at upper x locations
yl_interp = np.interp(xu_arr, xl_arr, yl_arr)
camber_x = xu_arr
camber_y = (yu_arr + yl_interp) / 2

# Full outline (closed)
outline_x = list(xu) + list(xl[1:])
outline_y = list(yu) + list(yl[1:])

fig, ax = plt.subplots(figsize=(12, 5), facecolor='#ffffff')
ax.set_facecolor('#f8f9fa')

# Fill airfoil
ax.fill(outline_x, outline_y, color='#dce8f5', zorder=2)

# Upper surface
ax.plot(xu, yu, color='#1565c0', linewidth=2, zorder=4, label='Upper surface')

# Lower surface
ax.plot(xl, yl, color='#1e88e5', linewidth=2, zorder=4, label='Lower surface')

# Camber line
ax.plot(camber_x, camber_y, color='#e53935', linewidth=1.2,
        linestyle='--', zorder=3, label='Camber line')

# Chord line
ax.plot([0, 1], [0, 0], color='#0d0d0d', linewidth=0.8,
        linestyle=':', zorder=3, label='Chord line')

# Styling
ax.set_aspect('equal')
ax.set_xlim(-0.05, 1.08)
ax.set_ylim(-0.12, 0.12)

ax.spines['bottom'].set_color("#272727")
ax.spines['left'].set_color('#272727')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(colors='#0d0d0d', labelsize=9)
ax.xaxis.label.set_color("#0D0D0D")
ax.yaxis.label.set_color('#0D0D0D')

ax.set_xlabel('x/c', fontsize=14, labelpad=8)
ax.set_ylabel('y/c', fontsize=14, labelpad=8)
ax.set_title('NACA 66-206', fontsize=20, color='#1a1a1a',
             fontweight='bold', pad=16, loc='left')

ax.legend(loc='upper right', fontsize=10, framealpha=0.8,
          labelcolor='#222222', edgecolor='#cccccc',
          facecolor='#ffffff')

ax.grid(True, color="#272727", linewidth=0.6, linestyle='-')

plt.tight_layout()
plt.show()

# %% [markdown]
# NACA 65-009 Empennage Airfoil

# %%
coords = [
    (1.00000000, 0.00000000), (0.99831631, 0.00001754), (0.99620619, 0.00005932),
    (0.99367163, 0.00012778), (0.99071500, 0.00022667), (0.98733905, 0.00035989),
    (0.98354691, 0.00053131), (0.97934212, 0.00074476), (0.97472855, 0.00100380),
    (0.96971045, 0.00131187), (0.96429241, 0.00167198), (0.95847941, 0.00208744),
    (0.95227663, 0.00255950), (0.94568973, 0.00309132), (0.93872439, 0.00368195),
    (0.93138679, 0.00433280), (0.92368299, 0.00504036), (0.91561979, 0.00580621),
    (0.90720375, 0.00662603), (0.89844194, 0.00749783), (0.88934199, 0.00842267),
    (0.87991153, 0.00939827), (0.87015839, 0.01042202), (0.86009064, 0.01149093),
    (0.84971672, 0.01260289), (0.83904533, 0.01375604), (0.82808532, 0.01494739),
    (0.81684566, 0.01617281), (0.80533568, 0.01742945), (0.79356503, 0.01871511),
    (0.78154290, 0.02002143), (0.76927927, 0.02134515), (0.75678417, 0.02268153),
    (0.74406769, 0.02402462), (0.73114045, 0.02537135), (0.71801363, 0.02672232),
    (0.70469775, 0.02807013), (0.69120363, 0.02940861), (0.67754242, 0.03073264),
    (0.66372494, 0.03203242), (0.64976271, 0.03330343), (0.63566726, 0.03453939),
    (0.62145025, 0.03573385), (0.60712417, 0.03688896), (0.59270034, 0.03799060),
    (0.57819127, 0.03903805), (0.56360866, 0.04001772), (0.54896507, 0.04092588),
    (0.53427275, 0.04175187), (0.51954454, 0.04249265), (0.50479298, 0.04313701),
    (0.49003115, 0.04368224), (0.47527243, 0.04413390), (0.46052987, 0.04448863),
    (0.44581663, 0.04474759), (0.43114589, 0.04491803), (0.41653062, 0.04499566),
    (0.40198381, 0.04498376), (0.38751827, 0.04489193), (0.37314670, 0.04472292),
    (0.35888156, 0.04448622), (0.34473517, 0.04418790), (0.33071978, 0.04383039),
    (0.31684758, 0.04341312), (0.30313052, 0.04293992), (0.28958058, 0.04240940),
    (0.27620950, 0.04182333), (0.26302868, 0.04118748), (0.25004965, 0.04050052),
    (0.23728344, 0.03976819), (0.22474132, 0.03898808), (0.21243387, 0.03816648),
    (0.20037196, 0.03730148), (0.18856587, 0.03639752), (0.17702600, 0.03545422),
    (0.16576218, 0.03447544), (0.15478430, 0.03346208), (0.14410160, 0.03241892),
    (0.13372383, 0.03134359), (0.12365991, 0.03023934), (0.11391850, 0.02910943),
    (0.10450859, 0.02795240), (0.09543812, 0.02677316), (0.08671541, 0.02557174),
    (0.07834765, 0.02435430), (0.07034198, 0.02312519), (0.06270603, 0.02188376),
    (0.05544716, 0.02062974), (0.04857284, 0.01936165), (0.04208989, 0.01808066),
    (0.03600375, 0.01679387), (0.03032007, 0.01550591), (0.02504545, 0.01421644),
    (0.02018797, 0.01292018), (0.01576040, 0.01159843), (0.01178062, 0.01022573),
    (0.00827911, 0.00876194), (0.00530995, 0.00715340), (0.00293191, 0.00539835),
    (0.00122529, 0.00352964), (0.00026662, 0.00165702), (0.00000000, 0.00000000),
]

lower = [
    (0.00000000, 0.00000000), (0.00026662, -0.00165702), (0.00122529, -0.00352964),
    (0.00293191, -0.00539835), (0.00530995, -0.00715340), (0.00827911, -0.00876194),
    (0.01178062, -0.01022573), (0.01576040, -0.01159843), (0.02018797, -0.01292018),
    (0.02504545, -0.01421644), (0.03032007, -0.01550591), (0.03600375, -0.01679387),
    (0.04208989, -0.01808066), (0.04857284, -0.01936165), (0.05544716, -0.02062974),
    (0.06270603, -0.02188376), (0.07034198, -0.02312519), (0.07834765, -0.02435430),
    (0.08671541, -0.02557174), (0.09543812, -0.02677316), (0.10450859, -0.02795240),
    (0.11391850, -0.02910943), (0.12365991, -0.03023934), (0.13372383, -0.03134359),
    (0.14410160, -0.03241892), (0.15478430, -0.03346208), (0.16576218, -0.03447544),
    (0.17702600, -0.03545422), (0.18856587, -0.03639752), (0.20037196, -0.03730148),
    (0.21243387, -0.03816648), (0.22474132, -0.03898808), (0.23728344, -0.03976819),
    (0.25004965, -0.04050052), (0.26302868, -0.04118748), (0.27620950, -0.04182333),
    (0.28958058, -0.04240940), (0.30313052, -0.04293992), (0.31684758, -0.04341312),
    (0.33071978, -0.04383039), (0.34473517, -0.04418790), (0.35888156, -0.04448622),
    (0.37314670, -0.04472292), (0.38751827, -0.04489193), (0.40198381, -0.04498376),
    (0.41653062, -0.04499566), (0.43114589, -0.04491803), (0.44581663, -0.04474759),
    (0.46052987, -0.04448863), (0.47527243, -0.04413390), (0.49003115, -0.04368224),
    (0.50479298, -0.04313701), (0.51954454, -0.04249265), (0.53427275, -0.04175187),
    (0.54896507, -0.04092588), (0.56360866, -0.04001772), (0.57819127, -0.03903805),
    (0.59270034, -0.03799060), (0.60712417, -0.03688896), (0.62145025, -0.03573385),
    (0.63566726, -0.03453939), (0.64976271, -0.03330343), (0.66372494, -0.03203242),
    (0.67754242, -0.03073264), (0.69120363, -0.02940861), (0.70469775, -0.02807013),
    (0.71801363, -0.02672232), (0.73114045, -0.02537135), (0.74406769, -0.02402462),
    (0.75678417, -0.02268153), (0.76927927, -0.02134515), (0.78154290, -0.02002143),
    (0.79356503, -0.01871511), (0.80533568, -0.01742945), (0.81684566, -0.01617281),
    (0.82808532, -0.01494739), (0.83904533, -0.01375604), (0.84971672, -0.01260289),
    (0.86009064, -0.01149093), (0.87015839, -0.01042202), (0.87991153, -0.00939827),
    (0.88934199, -0.00842267), (0.89844194, -0.00749783), (0.90720375, -0.00662603),
    (0.91561979, -0.00580621), (0.92368299, -0.00504036), (0.93138679, -0.00433280),
    (0.93872439, -0.00368195), (0.94568973, -0.00309132), (0.95227663, -0.00255950),
    (0.95847941, -0.00208744), (0.96429241, -0.00167198), (0.96971045, -0.00131187),
    (0.97472855, -0.00100380), (0.97934212, -0.00074476), (0.98354691, -0.00053131),
    (0.98733905, -0.00035989), (0.99071500, -0.00022667), (0.99367163, -0.00012778),
    (0.99620619, -0.00005932), (0.99831631, -0.00001754), (1.00000000, 0.00000000),
]

upper = coords  # upper surface goes from TE to LE

xu, yu = zip(*upper)
xl, yl = zip(*lower)

# Camber line
xu_arr, yu_arr = np.array(xu), np.array(yu)
xl_arr, yl_arr = np.array(xl), np.array(yl)
yl_interp = np.interp(xu_arr, xl_arr, yl_arr)
camber_x = xu_arr
camber_y = (yu_arr + yl_interp) / 2

# Full outline
outline_x = list(xu) + list(xl[1:])
outline_y = list(yu) + list(yl[1:])

fig, ax = plt.subplots(figsize=(12, 5), facecolor='#ffffff')
ax.set_facecolor('#f8f9fa')

ax.fill(outline_x, outline_y, color='#dce8f5', zorder=2)
ax.plot(xu, yu, color='#1565c0', linewidth=2, zorder=4, label='Upper surface')
ax.plot(xl, yl, color='#1e88e5', linewidth=2, zorder=4, label='Lower surface')
ax.plot(camber_x, camber_y, color='#e53935', linewidth=1.2,
        linestyle='--', zorder=3, label='Camber line')
ax.plot([0, 1], [0, 0], color='#0d0d0d', linewidth=0.8,
        linestyle=':', zorder=3, label='Chord line')

ax.set_aspect('equal')
ax.set_xlim(-0.05, 1.08)
ax.set_ylim(-0.12, 0.12)

ax.spines['bottom'].set_color('#272727')
ax.spines['left'].set_color('#272727')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(colors='#0d0d0d', labelsize=9)
ax.xaxis.label.set_color('#0d0d0d')
ax.yaxis.label.set_color('#0d0d0d')

ax.set_xlabel('x/c', fontsize=14, labelpad=8)
ax.set_ylabel('y/c', fontsize=14, labelpad=8)
ax.set_title('NACA 65-009', fontsize=20, color='#1a1a1a',
             fontweight='bold', pad=16, loc='left')

ax.legend(loc='upper right', fontsize=10, framealpha=0.8,
          labelcolor='#222222', edgecolor='#cccccc',
          facecolor='#ffffff')

ax.grid(True, color='#272727', linewidth=0.6, linestyle='-')

plt.tight_layout()
plt.show()
print("Saved.")
# Out:
# Saved.
